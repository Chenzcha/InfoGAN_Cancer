# %%
import pandas as pd
dataset=pd.read_csv('F:/Jupyter Notebook/Deep8/csv/label and box.csv', sep=',',header=None)
dataset.head(5)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.018374  0.300297  0.025319  0.337094  0.156523  0.018374  0.018374
# 1  0.018374  0.300297  0.025319  0.337094  0.156523  0.018374  0.018374
# 2  0.018374  0.300297  0.025319  0.337094  0.156523  0.018374  0.018374
# 3  0.018374  0.300297  0.025319  0.337094  0.156523  0.018374  0.018374
# 4  0.018374  0.300297  0.025319  0.337094  0.156523  0.018374  0.018374
#
#          7         8         9    10  11   12   13
# 0  0.088897  0.018374  0.018374    0   0  128  128
# 1  0.088897  0.018374  0.018374  128   0  256  128
# 2  0.088897  0.018374  0.018374  256   0  384  128
# 3  0.088897  0.018374  0.018374  384   0  512  128
# 4  0.088897  0.018374  0.018374  512   0  640  128

# %%
sof = dataset.iloc[:, 0:10].values
print(sof.shape)
# Out:
# (18252, 10)

# %%
import numpy as np


sof_re = np.reshape(sof, (117,156,-1))
print(sof_re.shape)
print(  sof_re[0,0,:]  )
# Out:
# (117, 156, 10)
# [0.01837421 0.30029651 0.02531942 0.33709371 0.15652259 0.01837421
#  0.01837421 0.08889677 0.01837421 0.01837421]

# %%
import seaborn as sns
import matplotlib.pylab as plt
from scipy.ndimage.filters import gaussian_filter

plt.subplots(figsize=(20,15))

sof_0 = sof_re[:,:,0]
#sof_0 = gaussian_filter(sof_0, sigma=1)
ax = sns.heatmap(sof_0)
plt.show()

# %%
sof_1 = sof_re[:,:,1]
print(sof_1.shape)
plt.subplots(figsize=(20,15))

ax = sns.heatmap(sof_1)
plt.show()
# Out:
# (117, 156)

# %%
sof_2 = sof_re[:,:,2]
print(sof_2.shape)
plt.subplots(figsize=(20,15))

ax = sns.heatmap(sof_2)
plt.show()
# Out:
# (117, 156)

# %%
sof_3 = sof_re[:,:,3]
print(sof_3.shape)
plt.subplots(figsize=(20,15))

ax = sns.heatmap(sof_3)
plt.show()
# Out:
# (117, 156)

# %%
sof_4 = sof_re[:,:,4]
print(sof_4.shape)
plt.subplots(figsize=(20,15))

ax = sns.heatmap(sof_4)
plt.show()
# Out:
# (117, 156)

# %%
sof_5 = sof_re[:,:,5]
print(sof_5.shape)
plt.subplots(figsize=(20,15))

ax = sns.heatmap(sof_5)
plt.show()
# Out:
# (117, 156)

# %%
sof_6 = sof_re[:,:,6]
print(sof_6.shape)
plt.subplots(figsize=(20,15))

ax = sns.heatmap(sof_6)
plt.show()
# Out:
# (117, 156)

# %%
sof_7 = sof_re[:,:,7]
print(sof_7.shape)
plt.subplots(figsize=(20,15))

ax = sns.heatmap(sof_7)
plt.show()
# Out:
# (117, 156)

# %%
sof_8 = sof_re[:,:,8]
print(sof_8.shape)
plt.subplots(figsize=(20,15))

ax = sns.heatmap(sof_8)
plt.show()
# Out:
# (117, 156)

# %%
sof_9 = sof_re[:,:,9]
print(sof_8.shape)
plt.subplots(figsize=(20,15))

ax = sns.heatmap(sof_9)
plt.show()
# Out:
# (117, 156)
